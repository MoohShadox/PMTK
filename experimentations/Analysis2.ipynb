# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
sns.set( rc={'text.usetex' : True})
MyFont = {'FontName', 'Times New Roman', 'FontSize', 25};


def get_exp(EXP):
    dfs=[]
    for p in os.listdir(EXP):
        if p.startswith("."):
            continue
        df = pd.read_csv(os.path.join(EXP, p))
        dfs.append(df)
    df = pd.concat(dfs).reset_index()
    
    df["evaluable"] = (df["correct"] + df["wrong"])
    df.loc[df["model"] == "CLF_UNION","model"] = "SVM"
    df.loc[df["model"] == "ORD-UNION","model"] = "ORD"
    df.loc[df["model"] == "CARD","model"] = "LPM"
    df["ACR"] = (df["correct"] ) / (df["total"] )
    df["AWR"] = (df["wrong"] ) / (df["total"] )
    
    df["RCR"] = (df["correct"] ) / (df["correct"] + df["wrong"] )
    df["RWR"] = (df["wrong"] ) / (df["correct"] + df["wrong"] )
    
    #df= df[df["budget"] >= 3]
    
    df["Inferred Preferences (T)"] = df["n_pref_output"]
    return df

# %%
EXP = "vCARD_03_03_12"
df = get_exp(EXP)

fig, (ax1, ax2) = plt.subplots(2, 1, sharex = True)
#fig.suptitle(r'$\alpha \in \{0.1, 0.3, 0.5, 0.7\}, p \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$, $t \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$')
s1 = sns.lineplot(data=df, x= "budget", y="ACR", hue = "model", ax = ax2)
s2 = sns.lineplot(data=df, x= "budget", y="Inferred Preferences (T)", hue = "model", ax = ax1)
s2.get_legend().remove()
s1.get_legend().remove()

plt.savefig(f"{EXP}.png",bbox_inches="tight")

# %%
EXP = "vCARD_01_01_12"
df = get_exp(EXP)

fig, (ax1, ax2) = plt.subplots(2, 1, sharex = True)
#fig.suptitle(r'$\alpha \in \{0.1, 0.3, 0.5, 0.7\}, p \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$, $t \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$')
s1 = sns.lineplot(data=df, x= "budget", y="ACR", hue = "model", ax = ax2)
s2 = sns.lineplot(data=df, x= "budget", y="Inferred Preferences (T)", hue = "model", ax = ax1)
s2.get_legend().remove()
s1.get_legend().remove()

plt.savefig(f"{EXP}.png",bbox_inches="tight")

# %%
EXP = "vTHETA_VS_NOTHETA_01_01_9"
df = get_exp(EXP)

df = df[df["real theta"] == False]

fig, (ax1, ax2) = plt.subplots(2, 1, sharex = True)
#fig.suptitle(r'$\alpha \in \{0.1, 0.3, 0.5, 0.7\}, p \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$, $t \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$')
s1 = sns.lineplot(data=df, x= "budget", y="ACR", hue = "model", ax = ax2)
s2 = sns.lineplot(data=df, x= "budget", y="Inferred Preferences (T)", hue = "model", ax = ax1)
s2.get_legend().remove()
s1.get_legend().remove()

plt.savefig(f"{EXP}.png",bbox_inches="tight")

# %%
EXP = "vTHETA_VS_NOTHETA_01_01_9"
df = get_exp(EXP)

df = df[df["model"] == "ORD"]
#df = df[df["real theta"] == False]

fig, (ax1, ax2) = plt.subplots(2, 1, sharex = True)
#fig.suptitle(r'$\alpha \in \{0.1, 0.3, 0.5, 0.7\}, p \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$, $t \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$')
s1 = sns.lineplot(data=df, x= "budget", y="ACR", hue = "real theta", ax = ax2)
s2 = sns.lineplot(data=df, x= "budget", y="Inferred Preferences (T)", hue = "real theta", ax = ax1)
s2.get_legend().remove()
#s1.get_legend().remove()

plt.savefig(f"{EXP}.png",bbox_inches="tight")

# %%
EXP = "vTHETA_VS_NOTHETA_03_03_9"
df = get_exp(EXP)

df = df[df["real theta"] == False]

fig, (ax1, ax2) = plt.subplots(2, 1, sharex = True)
#fig.suptitle(r'$\alpha \in \{0.1, 0.3, 0.5, 0.7\}, p \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$, $t \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$')
s1 = sns.lineplot(data=df, x= "budget", y="ACR", hue = "model", ax = ax2)
s2 = sns.lineplot(data=df, x= "budget", y="Inferred Preferences (T)", hue = "model", ax = ax1)
s2.get_legend().remove()
s1.get_legend().remove()

plt.savefig(f"{EXP}.png",bbox_inches="tight")

# %%
EXP = "vTHETA_VS_NOTHETA_03_03_9"
df = get_exp(EXP)

df = df[df["model"] == "ORD"]
#df = df[df["real theta"] == False]

fig, (ax1, ax2) = plt.subplots(2, 1, sharex = True)
#fig.suptitle(r'$\alpha \in \{0.1, 0.3, 0.5, 0.7\}, p \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$, $t \in \{0.1, 0.3, 0.5, 0.7, 0.9\}$')
s1 = sns.lineplot(data=df, x= "budget", y="ACR", hue = "real theta", ax = ax2)
s2 = sns.lineplot(data=df, x= "budget", y="Inferred Preferences (T)", hue = "real theta", ax = ax1)
s2.get_legend().remove()
#s1.get_legend().remove()

plt.savefig(f"{EXP}.png",bbox_inches="tight")
